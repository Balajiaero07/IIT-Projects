# %%
import tweepy
import csv
import pandas as pd
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import matplotlib.pyplot as plt
import numpy as np
from textblob import TextBlob
import os 
import pandas as pd
import os
import os
import pandas as pd
import numpy as np
import csv
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from collections import Counter
from string import punctuation
import nltk
from string import punctuation
from operator import itemgetter
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import NMF, LatentDirichletAllocation
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()
import string 
from collections import Counter
from nltk import word_tokenize, pos_tag, pos_tag_sents
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize
positive = pd.read_csv('pos.csv', header=None)
negative = pd.read_csv('neg.csv', header=None)

positive[1] = positive[1].str.replace('http\S+|www.\S+', '', case=False)
positive[1] = positive[1].str.replace('b', '', case=False)
positive[1] = positive[1].str.replace('RT', '', case=False)

negative[1] = negative[1].str.replace('http\S+|www.\S+', '', case=False)
negative[1] = negative[1].str.replace('b', '', case=False)
negative[1] = negative[1].str.replace('RT', '', case=False)

positive_no_pun = positive[1].str.replace('[^\w\s]','')
negative_no_pun = negative[1].str.replace('[^\w\s]','')

#data = pd.concat([positive_no_pun,negative_no_pun])
data = positive_no_pun

# %%
tokenized_sents = []
tokenized_sents = [word_tokenize(i) for i in data]
noun_words = []
for j in range(1,len(tokenized_sents)):
    tagged = nltk.pos_tag(tokenized_sents[j])
    for item in tagged:
        if item[1] == 'N' or item[1] == 'NN' or item[1] == 'NNP' or item[1] == 'NNS' or item[1] == 'NNPS':
            noun_words.append(item[0])

# %%
from collections import Counter
x = Counter(noun_words)
x.most_common()
# Out:
# [('health', 7030),
#  ('ihday', 5994),
#  ('amp', 3136),
#  ('Mersal', 2744),
#  ('organicfood', 2727),
#  ('xe2x80xa6', 2208),
#  ('wishes', 1879),
#  ('FREE', 1732),
#  ('Health', 1722),
#  ('Co', 1647),
#  ('MsKajalAggarwal', 1643),
#  ('food', 1638),
#  ('superstar', 1638),
#  ('actors', 1637),
#  ('HappyihdayVijay', 1634),
#  ('Out', 1542),
#  ('Organic', 1539),
#  ('USINESS', 1535),
#  ('FREEn', 1535),
#  ('Commissions', 1535),
#  ('Weeklynxf0x9fx92x', 1535),
#  ('Personalized', 1534),
#  ('Arasan', 1369),
#  ('Theatreu', 1367),
#  ('Therikka', 1367),
#  ('Gelikka', 1367),
#  ('Vaaraan', 1367),
#  ('SonyMusicSouth', 1366),
#  ('Thalapathy', 1357),
#  ('Happy', 1351),
#  ('actorvijay', 1336),
#  ('sir', 1225),
#  ('So', 1206),
#  ('y', 1193),
#  ('CDOilProducts', 1106),
#  ('day', 999),
#  ('Wesixe2x80xa6', 944),
#  ('Sarkar', 940),
#  ('Thank', 839),
#  ('Vijay', 827),
#  ('people', 810),
#  ('OrganicFood', 788),
#  ('HDThalapathyVIJAY', 786),
#  ('fans', 766),
#  ('Wishing', 754),
#  ('year', 736),
#  ('time', 721),
#  ('Tell', 688),
#  ('Tamil', 683),
#  ('Food', 675),
#  ('New', 651),
#  ('Day', 635),
#  ('actor', 632),
#  ('light', 622),
#  ('pa', 621),
#  ('CamridgeAnalytica', 619),
#  ('success', 606),
#  ('darkness', 602),
#  ('doctor_oxford', 601),
#  ('kicxe2x80xa6', 601),
#  ('Wesxe2x80xa6', 590),
#  ('Very', 584),
#  ('Will', 572),
#  ('Theri', 570),
#  ('care', 569),
#  ('singer', 564),
#  ('movies', 561),
#  ('Orwell', 558),
#  ('Saavn', 557),
#  ('playack', 557),
#  ('Mersaltastic', 557),
#  ('xf0x9fxa4xa9xf0x9fx91x89xe2x80xa6', 557),
#  ('journalism', 556),
#  ('Carole', 549),
#  ('proud', 548),
#  ('sathishmsk', 548),
#  ('love', 546),
#  ('Kaththi', 545),
#  ('paxe2x80xa6', 542),
#  ('ause', 541),
#  ('DancingTheMind', 541),
#  ('Cadwalladr', 541),
#  ('airavaa', 536),
#  ('way', 535),
#  ('Im', 534),
#  ('threats', 533),
#  ('prizennLest', 529),
#  ('frank', 528),
#  ('mass', 502),
#  ('ACTION', 501),
#  ('First', 496),
#  ('SARKAR', 493),
#  ('today', 491),
#  ('reasons', 485),
#  ('Wish', 482),
#  ('world', 471),
#  ('e', 466),
#  ('ThalapathyVijay', 457),
#  ('A', 454),
#  ('Online', 453),
#  ('Congress', 433),
#  ('OWN', 430),
#  ('lack', 429),
#  ('community', 429),
#  ('INCIndia', 428),
#  ('voices', 417),
#  ('HappyihdayThalapathyVijay', 416),
#  ('goons', 416),
#  ('RajatSethi86', 414),
#  ('look', 394),
#  ('yourxe2x80xa6', 392),
#  ('life', 391),
#  ('stars', 390),
#  ('needs', 387),
#  ('wealth', 385),
#  ('happiness', 383),
#  ('xe2x80x99s', 381),
#  ('i_Sri_Divya', 379),
#  ('appeal', 379),
#  ('yupptv', 375),
#  ('Natural', 374),
#  ('xf0x9fx8ex81xf0x9fx8ex82', 374),
#  ('Alongside', 374),
#  ('joy', 373),
#  ('Look', 370),
#  ('maindotorg', 367),
#  ('Foods', 359),
#  ('xf0x9fx92x90xf0x9fx92x90xf0x9fx92x90', 337),
#  ('enefits', 335),
#  ('insurance', 332),
#  ('Mental', 328),
#  ('laels', 325),
#  ('yours', 324),
#  ('gautamitads', 324),
#  ('endeavors', 324),
#  ('moms', 323),
#  ('someone', 323),
#  ('Social', 319),
#  ('man', 319),
#  ('tax', 318),
#  ('etter', 314),
#  ('Nana', 313),
#  ('HEALTH', 312),
#  ('offl_Lawrence', 311),
#  ('Raghavendra', 311),
#  ('swamy', 311),
#  ('products', 308),
#  ('Fans', 306),
#  ('Great', 303),
#  ('Farm', 294),
#  ('farmill', 290),
#  ('GMOs', 288),
#  ('organics', 287),
#  ('Keep', 283),
#  ('ehalf', 274),
#  ('xe2x9exa1xefx8x8f', 273),
#  ('TAKE', 270),
#  ('Dance', 270),
#  ('xf0x9fx8ex82', 269),
#  ('IS', 269),
#  ('Good', 266),
#  ('txe2x80xa6', 263),
#  ('foods', 262),
#  ('WholeFoods', 262),
#  ('Thanks', 261),
#  ('andxe2x80xa6', 259),
#  ('No', 258),
#  ('OrganicConsumer', 258),
#  ('Chennai', 257),
#  ('Delhi', 253),
#  ('HappyihdayThalapathy', 253),
#  ('fitness', 252),
#  ('strategy', 245),
#  ('Healthy', 244),
#  ('Give', 243),
#  ('Trumps', 243),
#  ('millions', 243),
#  ('shows', 241),
#  ('Check', 240),
#  ('World', 240),
#  ('reaks', 238),
#  ('SenSanders', 236),
#  ('VegetarianNews2', 235),
#  ('UK', 234),
#  ('URGENT', 234),
#  ('illionaires', 233),
#  ('Securityxe2x80xa6', 233),
#  ('NEW', 231),
#  ('Top', 231),
#  ('TOP', 230),
#  ('ill', 228),
#  ('Join', 227),
#  ('NEEDED', 227),
#  ('Chengelpet', 224),
#  ('circuit', 224),
#  ('todaynnPokkirri', 224),
#  ('ARMurugadoss', 224),
#  ('study', 223),
#  ('team', 223),
#  ('Millions', 223),
#  ('Ajaychairman', 223),
#  ('RereleasenKaththinMersalnTherinairxe2x80xa6', 220),
#  ('organicfoodxe2x80xa6', 218),
#  ('XXXtenntacion', 215),
#  ('Less', 213),
#  ('NOW', 213),
#  ('US', 212),
#  ('P', 211),
#  ('How', 211),
#  ('Sir', 211),
#  ('service', 210),
#  ('Man', 210),
#  ('organicfxe2x80xa6', 208),
#  ('God', 208),
#  ('ixe2x80xa6', 208),
#  ('Ajith', 208),
#  ('Itxe2x80x99s', 206),
#  ('Superstar', 204),
#  ('stas', 203),
#  ('Shop', 200),
#  ('money', 200),
#  ('More', 199),
#  ('years', 198),
#  ('everything', 198),
#  ('hxe2x80xa6', 197),
#  ('merahtu1k', 196),
#  ('Fresh', 196),
#  ('Junk', 195),
#  ('Who', 195),
#  ('My', 194),
#  ('motivation', 192),
#  ('HydroponicLife1', 188),
#  ('Amazon', 188),
#  ('children', 188),
#  ('Please', 188),
#  ('data', 188),
#  ('King', 188),
#  ('Veggiesand', 187),
#  ('Foodin', 187),
#  ('axe2x80xa6', 186),
#  ('avatar', 184),
#  ('RO', 183),
#  ('healthxe2x80xa6', 183),
#  ('inandoutstore', 182),
#  ('Shantipath', 182),
#  ('GMO', 181),
#  ('market', 179),
#  ('FL', 176),
#  ('Many', 175),
#  ('Life', 172),
#  ('Super', 172),
#  ('PRIORITYnHEECHULS', 171),
#  ('Actor', 171),
#  ('wxe2x80xa6', 170),
#  ('tn_ajith', 169),
#  ('nHDVijayyAJITHFxe2x80xa6', 169),
#  ('Whole', 167),
#  ('media', 164),
#  ('TicketNew', 164),
#  ('ORGANIC', 163),
#  ('n', 162),
#  ('healthcoach', 161),
#  ('Learn', 160),
#  ('choice', 160),
#  ('research', 160),
#  ('work', 160),
#  ('Find', 160),
#  ('thanks', 159),
#  ('Care', 158),
#  ('healthandwellness', 158),
#  ('farmers', 157),
#  ('Yoga', 156),
#  ('Market', 155),
#  ('Orgxe2x80xa6', 155),
#  ('week', 155),
#  ('agriculture', 154),
#  ('home', 152),
#  ('Love', 152),
#  ('May', 152),
#  ('fan', 152),
#  ('Honey', 151),
#  ('LIVE', 151),
#  ('Eat', 150),
#  ('organic', 149),
#  ('lot', 149),
#  ('One', 148),
#  ('Siva_Kaikeyan', 148),
#  ('VijayTeamOnline', 147),
#  ('Jars', 147),
#  ('cxe2x80xa6', 146),
#  ('Ixe2x80x99m', 146),
#  ('healthyfood', 145),
#  ('fruit', 145),
#  ('June', 145),
#  ('rameshlaus', 144),
#  ('Daily', 143),
#  ('things', 143),
#  ('access', 143),
#  ('youre', 142),
#  ('TO', 142),
#  ('toxe2x80xa6', 141),
#  ('xe2x9cx85', 140),
#  ('one', 139),
#  ('ody', 138),
#  ('summer', 137),
#  ('share', 137),
#  ('impact', 137),
#  ('Enteaining', 137),
#  ('DrWardondTV', 136),
#  ('idea', 136),
#  ('Masses', 136),
#  ('nutrition', 135),
#  ('Most', 135),
#  ('poster', 135),
#  ('Numers', 135),
#  ('farm', 134),
#  ('yxe2x80xa6', 134),
#  ('Floorxe2x80xa6', 134),
#  ('Nice', 133),
#  ('sunpictures', 133),
#  ('Do', 132),
#  ('Home', 132),
#  ('FarmGreenworld', 132),
#  ('Farmers', 132),
#  ('evidence', 132),
#  ('vegetales', 130),
#  ('company', 130),
#  ('ay', 130),
#  ('Get', 130),
#  ('Diet', 130),
#  ('sirxf0x9fx98x8aest', 130),
#  ('ut', 129),
#  ('Winter', 128),
#  ('garden', 128),
#  ('Faceook', 128),
#  ('xf0x9fx98x8axf0x9fx91x8d', 128),
#  ('Dear', 127),
#  ('water', 126),
#  ('story', 125),
#  ('Simple', 125),
#  ('reakfast', 124),
#  ('Watch', 124),
#  ('Products', 124),
#  ('orgaxe2x80xa6', 123),
#  ('log', 123),
#  ('sales', 122),
#  ('Monsanto', 122),
#  ('ecause', 121),
#  ('rawfood', 121),
#  ('Your', 121),
#  ('range', 119),
#  ('NHS', 119),
#  ('uy', 118),
#  ('Free', 118),
#  ('government', 118),
#  ('issues', 118),
#  ('Come', 117),
#  ('taste', 117),
#  ('fault', 117),
#  ('repo', 116),
#  ('SaraRSiskind', 116),
#  ('jimathers', 116),
#  ('video', 116),
#  ('news', 116),
#  ('Foodxe2x80xa6', 116),
#  ('Vijays', 116),
#  ('MondayMotivation', 116),
#  ('Are', 115),
#  ('xe2x80x93', 115),
#  ('Mass', 115),
#  ('Dont', 114),
#  ('tea', 114),
#  ('People', 114),
#  ('fruits', 113),
#  ('oxe2x80xa6', 113),
#  ('Looks', 112),
#  ('IN', 112),
#  ('sues', 112),
#  ('TIMTHETOOLMANN', 112),
#  ('role', 111),
#  ('thingmake', 111),
#  ('flu', 111),
#  ('yoga', 111),
#  ('Consumers', 111),
#  ('ack', 111),
#  ('friends', 111),
#  ('forxe2x80xa6', 111),
#  ('AMDWaters', 111),
#  ('education', 111),
#  ('growth', 110),
#  ('information', 110),
#  ('caoon', 110),
#  ('farming', 110),
#  ('lxe2x80xa6', 110),
#  ('hea', 109),
#  ('services', 109),
#  ('difference', 108),
#  ('kids', 108),
#  ('U', 108),
#  ('family', 108),
#  ('Product', 108),
#  ('Tweets', 108),
#  ('OrganicFarming', 107),
#  ('All', 107),
#  ('agriculturexe2x80xa6', 107),
#  ('Sunday', 106),
#  ('xf0x9fx98x8e', 106),
#  ('person', 106),
#  ('masses', 106),
#  ('healthylife', 105),
#  ('everyone', 105),
#  ('place', 105),
#  ('campaign', 105),
#  ('organicxe2x80xa6', 105),
#  ('illion', 105),
#  ('something', 105),
#  ('minutes', 105),
#  ('soil', 104),
#  ('India', 104),
#  ('reason', 104),
#  ('National', 104),
#  ('recipe', 103),
#  ('Organicfood', 103),
#  ('planet', 103),
#  ('Poster', 103),
#  ('Centre', 102),
#  ('colds', 102),
#  ('South', 102),
#  ('LifeChangingWellness', 102),
#  ('peace', 102),
#  ('NHI', 102),
#  ('simplelifehappyhome', 101),
#  ('General', 101),
#  ('grocery', 100),
#  ('fire', 100),
#  ('film', 100),
#  ('rother', 100),
#  ('FOOD', 99),
#  ('morning', 99),
#  ('risk', 99),
#  ('costs', 98),
#  ('snack', 97),
#  ('NoGMO', 97),
#  ('supplements', 97),
#  ('videos', 97),
#  ('days', 96),
#  ('weekend', 96),
#  ('ALL', 96),
#  ('thexe2x80xa6', 96),
#  ('Impoant', 96),
#  ('hope', 96),
#  ('Today', 95),
#  ('News', 95),
#  ('aicle', 95),
#  ('xf0x9fx94xa5', 95),
#  ('Likes', 95),
#  ('sxe2x80xa6', 94),
#  ('Farms', 94),
#  ('Returns', 94),
#  ('movie', 94),
#  ('ThenandalFilms', 94),
#  ('posts', 93),
#  ('Agro', 93),
#  ('thing', 93),
#  ('Happiest', 93),
#  ('organixe2x80xa6', 92),
#  ('suppo', 92),
#  ('nothing', 91),
#  ('animation', 91),
#  ('oppounity', 91),
#  ('diet', 91),
#  ('nice', 91),
#  ('xe2x80x9cFructus', 90),
#  ('Fairxe2x80x9d', 90),
#  ('nOrganicFarmersFair', 90),
#  ('TOFF', 90),
#  ('office', 90),
#  ('prolems', 90),
#  ('Txe2x80xa6', 90),
#  ('Anna', 90),
#  ('Sarkars', 90),
#  ('DietingForLife', 89),
#  ('claims', 89),
#  ('ya', 89),
#  ('hers', 89),
#  ('Stay', 89),
#  ('Live', 89),
#  ('case', 89),
#  ('lood', 89),
#  ('industry', 88),
#  ('Foamy', 88),
#  ('Link', 88),
#  ('professionals', 88),
#  ('organxe2x80xa6', 88),
#  ('technology', 88),
#  ('rymannionxo', 88),
#  ('Mad', 88),
#  ('islanders', 88),
#  ('FDA', 87),
#  ('Monday', 87),
#  ('USDA', 87),
#  ('healthcare', 87),
#  ('arihant_aspire', 87),
#  ('ASPIRE', 87),
#  ('AN', 87),
#  ('WORLD', 87),
#  ('ARIHANT', 87),
#  ('Fructus_io', 86),
#  ('AmsterdamRai', 86),
#  ('veggies', 86),
#  ('system', 86),
#  ('IndiaToday', 86),
#  ('sugar', 85),
#  ('chemicals', 85),
#  ('store', 85),
#  ('use', 85),
#  ('vijay', 85),
#  ('Celerated', 85),
#  ('Friday', 84),
#  ('onus', 84),
#  ('Sales', 84),
#  ('quality', 84),
#  ('WITH', 84),
#  ('Rose', 84),
#  ('xf0x9fx92x90', 84),
#  ('Records', 84),
#  ('nITVideonMore', 84),
#  ('pxe2x80xa6', 83),
#  ('delivery', 83),
#  ('tips', 83),
#  ('rikidavies1', 83),
#  ('thxe2x80xa6', 83),
#  ('energy', 83),
#  ('htxe2x80xa6', 82),
#  ('Farming', 82),
#  ('orxe2x80xa6', 82),
#  ('sustainaility', 82),
#  ('ihdaxe2x80xa6', 82),
#  ('sarkar', 82),
#  ('meat', 81),
#  ('vegan', 81),
#  ('Read', 81),
#  ('Mills', 81),
#  ('Proud', 81),
#  ('ASPIREnnOrganic', 81),
#  ('PanersnnKedia', 81),
#  ('Share', 80),
#  ('event', 80),
#  ('Organics', 80),
#  ('GMOxe2x80xa6', 80),
#  ('seeds', 80),
#  ('Just', 80),
#  ('history', 80),
#  ('Vodacom', 80),
#  ('Users', 80),
#  ('Liked', 80),
#  ('ingredients', 79),
#  ('produce', 79),
#  ('lives', 79),
#  ('Second', 79),
#  ('Camridge', 79),
#  ('sale', 78),
#  ('Gloal', 78),
#  ('Inc', 78),
#  ('program', 78),
#  ('record', 78),
#  ('jo', 78),
#  ('Which', 78),
#  ('Dr', 78),
#  ('Trump', 78),
#  ('AdvarryRoux', 78),
#  ('ofxe2x80xa6', 78),
#  ('Media', 78),
#  ('SL', 78),
#  ('honey', 77),
#  ('hexe2x80xa6', 77),
#  ('HUGE', 77),
#  ('experience', 77),
#  ('cancer', 77),
#  ('example', 77),
#  ('state', 77),
#  ('Additives', 77),
#  ('Go', 76),
#  ('exe2x80xa6', 76),
#  ('fxe2x80xa6', 76),
#  ('Did', 76),
#  ('women', 76),
#  ('anxe2x80xa6', 76),
#  ('ActorVijay', 76),
#  ('ig', 75),
#  ('vegansofig', 75),
#  ('organicfoxe2x80xa6', 75),
#  ('need', 75),
#  ('safety', 75),
#  ('Clearly', 75),
#  ('Crafted', 75),
#  ('milk', 74),
#  ('Full', 74),
#  ('Industry', 74),
#  ('guests', 74),
#  ('Cancer', 74),
#  ('Na', 74),
#  ('HealthyEating', 73),
#  ('Summer', 73),
#  ('future', 73),
#  ('salad', 73),
#  ('arrahman', 73),
#  ('Movie', 73),
#  ('darling', 73),
#  ('FLnn2', 73),
#  ('Delicious', 72),
#  ('RestaurantKa', 72),
#  ('ways', 72),
#  ('parents', 72),
#  ('coffee', 72),
#  ('order', 72),
#  ('Vegan', 72),
#  ('wait', 72),
#  ('itxe2x80x99s', 72),
#  ('gym', 72),
#  ('racism', 72),
#  ('Hemarukmani1', 72),
#  ('Tittle', 72),
#  ('paro_nair', 72),
#  ('sector', 71),
#  ('El', 71),
#  ('LifethymeMarket', 71),
#  ('post', 71),
#  ('Fruit', 71),
#  ('Well', 71),
#  ('whatxe2x80x99s', 71),
#  ('Lyricist_Vivek', 71),
#  ('Analytica', 71),
#  ('Pure', 70),
#  ('Enjoy', 70),
#  ('fuel', 70),
#  ('offer', 70),
#  ('Manual', 70),
#  ('eat', 70),
#  ('sta', 70),
#  ('snoodjuice', 70),
#  ('ale', 70),
#  ('police', 70),
#  ('sleep', 70),
#  ('reasts', 70),
#  ('topics', 70),
#  ('army', 70),
#  ('movement', 69),
#  ('Green', 69),
#  ('DRHealtHnew', 69),
#  ('Organo', 69),
#  ('Danue', 69),
#  ('hyper', 69),
#  ('Can', 69),
#  ('pictures', 69),
#  ('Minister', 69),
#  ('language', 69),
#  ('Mentions', 69),
#  ('fact', 68),
#  ('diseases', 68),
#  ('hours', 68),
#  ('rest', 68),
#  ('womens', 68),
#  ('Human', 68),
#  ('law', 68),
#  ('Twitter', 68),
#  ('Heard', 68),
#  ('humleness', 68),
#  ('nikkisaidwhat_', 68),
#  ('launch', 67),
#  ('Jos', 67),
#  ('Former', 67),
#  ('security', 67),
#  ('anna', 67),
#  ('lunch', 66),
#  ('environment', 66),
#  ('right', 66),
#  ('lockchain', 66),
#  ('Garden', 66),
#  ('Always', 66),
#  ('ad', 66),
#  ('i', 66),
#  ('Ause', 66),
#  ('timexe2x80xa6', 66),
#  ('point', 66),
#  ('See', 65),
#  ('rise', 65),
#  ('Happiness', 65),
#  ('healtxe2x80xa6', 65),
#  ('kind', 65),
#  ('HealthyFood', 65),
#  ('cuts', 65),
#  ('From', 65),
#  ('City', 65),
#  ('aout', 65),
#  ('skin', 65),
#  ('Shadowhunters', 65),
#  ('country', 65),
#  ('gloal', 64),
#  ('Car', 64),
#  ('help', 64),
#  ('NonGMO', 64),
#  ('Visit', 64),
#  ('healxe2x80xa6', 64),
#  ('tools', 64),
#  ('Group', 64),
#  ('ShumDarioNews', 64),
#  ('class', 64),
#  ('InandOutstore', 63),
#  ('PCL', 63),
#  ('station', 63),
#  ('LodhiRoad', 63),
#  ('Milk', 63),
#  ('sign', 63),
#  ('age', 63),
#  ('employee', 63),
#  ('HealthyLiving', 62),
#  ('shaifalisinghc', 62),
#  ('Healthfood', 62),
#  ('enefit', 62),
#  ('gofarmz', 62),
#  ('consumers', 62),
#  ('paper', 62),
#  ('Radio', 62),
#  ('West', 62),
#  ('Real', 62),
#  ('luck', 62),
#  ('xf0x9fxa4x97xf0x9fx98x8d', 62),
#  ('Tag', 62),
#  ('enteainer', 62),
#  ('aromatherapy', 62),
#  ('Red', 61),
#  ('online', 61),
#  ('Experience', 61),
#  ('drugs', 61),
#  ('Were', 61),
#  ('ayer', 61),
#  ('Alzheimerxe2x80x99s', 61),
#  ('apps', 61),
#  ('mxe2x80xa6', 60),
#  ('ones', 60),
#  ('dr_health', 60),
#  ('meal', 60),
#  ('Letxe2x80x99s', 60),
#  ('Make', 60),
#  ('goodness', 60),
#  ('process', 60),
#  ('Sma', 60),
#  ('talk', 60),
#  ('impoant', 60),
#  ('Greek', 60),
#  ('honour', 60),
#  ('pride', 60),
#  ('MERSAL', 60),
#  ('usiness', 59),
#  ('Time', 59),
#  ('diets', 59),
#  ('companies', 59),
#  ('Ive', 59),
#  ('Could', 59),
#  ('Yogu', 59),
#  ('demand', 59),
#  ('rates', 59),
#  ('rain', 59),
#  ('increases', 59),
#  ('anxiety', 59),
#  ('actorvijaynAtlee_dirnarrahman', 59),
#  ('Murxe2x80xa6', 59),
#  ('sayyeshaa', 59),
#  ('xf0x9fx92x83xf0x9fx92x83nHDThalapathiVIJAY', 59),
#  ('nHDThalapathyVijay', 59),
#  ('xf0x9fx98x8dxf0x9fx98x8dxf0x9fx98x8d', 59),
#  ('SARKARxe2x80x99s', 59),
#  ('aies', 58),
#  ('app', 58),
#  ('months', 58),
#  ('step', 58),
#  ('level', 58),
#  ('PHE_uk', 58),
#  ('PM', 58),
#  ('Monsaxe2x80xa6', 58),
#  ('CamridgeAnalyticxe2x80xa6', 58),
#  ('greens', 57),
#  ('Raw', 57),
#  ('eauty', 57),
#  ('glutenfree', 57),
#  ('fun', 57),
#  ('science', 57),
#  ('nexe2x80xa6', 57),
#  ('Koko', 57),
#  ('eastxsea', 57),
#  ('HEECHULS', 57),
#  ('PRxe2x80xa6', 57),
#  ('York', 57),
#  ('countries', 57),
#  ('Eating', 56),
#  ('Page', 56),
#  ('types', 56),
#  ('actionxe2x80xa6', 56),
#  ('Study', 56),
#  ('funding', 56),
#  ('rexit', 56),
#  ('thalapathy', 56),
#  ('Diwali', 56),
#  ('NGK', 56),
#  ('Ayurvedicmedicine', 56),
#  ('ampxe2x80xa6', 55),
#  ('Future', 55),
#  ('medicine', 55),
#  ('SeasonForestRow', 55),
#  ('note', 55),
#  ('violence', 55),
#  ('Lots', 55),
#  ('gorilla', 55),
#  ('Water', 55),
#  ('gift', 54),
#  ('lots', 54),
#  ('worrying', 54),
#  ('doctor', 54),
#  ('Oil', 54),
#  ('Mix', 54),
#  ('Fitness', 54),
#  ('polixe2x80xa6', 54),
#  ('UN', 54),
#  ('hero', 54),
#  ('stills', 54),
#  ('orgxe2x80xa6', 53),
#  ('nature', 53),
#  ('Ayurvedic', 53),
#  ('Drink', 53),
#  ('effect', 53),
#  ('spo', 53),
#  ('Paleo', 53),
#  ('stress', 53),
#  ('Price', 53),
#  ('Cant', 53),
#  ('Young', 53),
#  ('Hi', 53),
#  ('Amazing', 53),
#  ('Shri', 53),
#  ('VETRIMAARAN', 53),
#  ('xf0x9fx98x8exf0x9fx94xa5', 53),
#  ('xe2x80x94', 52),
#  ('Wow', 52),
#  ('Every', 52),
#  ('FOAMY', 52),
#  ('worldwide', 52),
#  ('plant', 52),
#  ('staup', 52),
#  ('farmer', 52),
#  ('Perfect', 52),
#  ('Government', 52),
#  ('school', 52),
#  ('Tweet', 52),
#  ('towards', 52),
#  ('chance', 52),
#  ('jsteenhuisen', 52),
#  ('Savage2I', 52),
#  ('ManoalaV', 52),
#  ('Iowa', 52),
#  ('RWPUSA', 52),
#  ('loadernAnd', 52),
#  ('payer', 52),
#  ('insurancennAlways', 52),
#  ('righxe2x80xa6', 52),
#  ('TwitterIndia', 52),
#  ('juice', 51),
#  ('winter', 51),
#  ('oil', 51),
#  ('wise', 51),
#  ('wellness', 51),
#  ('awareness', 51),
#  ('Tips', 51),
#  ('Isnt', 51),
#  ('antioxidants', 51),
#  ('Moringa', 51),
#  ('Hxe2x80xa6', 51),
#  ('inxe2x80xa6', 51),
#  ('profsassy', 51),
#  ('xe2x80x9cexcellencexe2x80x9d', 51),
#  ('haringer', 51),
#  ('Youxe2x80x99re', 51),
#  ('staff', 51),
#  ('SenSchumer', 51),
#  ('Indiana', 51),
#  ('scandal', 51),
#  ('moment', 51),
#  ('injuries', 51),
#  ('Thuppakki', 51),
#  ('mentions', 51),
#  ('AD', 51),
#  ('ox', 50),
#  ('GoldenRice', 50),
#  ('markets', 50),
#  ('Saturday', 50),
#  ('tomorrow', 50),
#  ('Prime', 50),
#  ('corner', 50),
#  ('Herexe2x80x99s', 50),
#  ('THE', 50),
#  ('California', 50),
#  ('Really', 50),
#  ('Americans', 50),
#  ('resources', 50),
#  ('dies', 50),
#  ('making', 50),
#  ('survey', 50),
#  ('saotage', 50),
#  ('land', 49),
#  ('farms', 49),
#  ('Choose', 49),
#  ('FridayFeeling', 49),
#  ('OrganicIndia', 49),
#  ('sweet', 49),
#  ('Research', 49),
#  ('issue', 49),
#  ('Fighting', 49),
#  ('TheDrWardondShow', 49),
#  ('facilities', 49),
#  ('EU', 49),
#  ('DaysnHappyihday', 49),
#  ('shop', 48),
#  ('Use', 48),
#  ('foodie', 48),
#  ('SO', 48),
#  ('Universe', 48),
#  ('MediciMedicine_', 48),
#  ('living', 48),
#  ('Easy', 48),
#  ('end', 48),
#  ('seasnax', 48),
#  ('lueerries', 48),
#  ('mind', 48),
#  ('Digital', 48),
#  ('mentalhealth', 48),
#  ('cnnrk', 48),
#  ('apes', 48),
#  ('wonder', 48),
#  ('Films', 48),
#  ('Rawjuce', 48),
#  ('Show', 47),
#  ('TokenSale', 47),
#  ('runch', 47),
#  ('Seeds', 47),
#  ('photo', 47),
#  ('LiveOrganicl', 47),
#  ('peppers', 47),
#  ('potatoes', 47),
#  ('dexe2x80xa6', 47),
#  ('disease', 47),
#  ('population', 47),
#  ('Oxe2x80xa6', 47),
#  ('Depament', 47),
#  ('Want', 47),
#  ('ChAnYeOl', 47),
#  ('HyUnG', 47),
#  ('HiS', 47),
#  ('pHoNE', 47),
#  ('sOmEtiMes', 47),
#  ('hiM', 47),
#  ('GoOd', 47),
#  ('foR', 47),
#  ('hEalTh', 47),
#  ('Halal', 47),
#  ('herpes', 47),
#  ('heas', 47),
#  ('anandshank', 47),
#  ('comoxe2x80xa6', 47),
#  ('product', 46),
#  ('ready', 46),
#  ('norganicfood', 46),
#  ('coconut', 46),
#  ('pancakes', 46),
#  ('PeakHealthSuppl', 46),
#  ('ioSuperfood', 46),
#  ('Latest', 46),
#  ('night', 46),
#  ('sauce', 46),
#  ('Award', 46),
#  ('pressure', 46),
#  ('Salts', 46),
#  ('agency', 46),
#  ('course', 46),
#  ('families', 46),
#  ('ass', 46),
#  ('students', 46),
#  ('Gaza', 46),
#  ('Kaxe2x80xa6', 46),
#  ('Hope', 45),
#  ('Smoothie', 45),
#  ('Wexe2x80x99re', 45),
#  ('round', 45),
#  ('cugnierusa', 45),
#  ('EthicalHedMag', 45),
#  ('Toxic', 45),
#  ('patterns', 45),
#  ('pesticides', 45),
#  ('Gardening', 45),
#  ('dinner', 45),
#  ('High', 45),
#  ...]
