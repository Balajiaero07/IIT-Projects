# %%
import os
import pandas as pd
import numpy as np
import csv
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from collections import Counter
from string import punctuation
import nltk
from string import punctuation
from operator import itemgetter
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import NMF, LatentDirichletAllocation

from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()
import string 
from collections import Counter
from nltk import word_tokenize, pos_tag, pos_tag_sents
import matplotlib.pyplot as plt

# %%
os.chdir("E:\\Consultancy\\Crayon")
df = DataFrame.from_csv("100K_Restaurants_reviews.tsv", sep="\t")

# %%
no_features = 1000 #top 10000 features are selected
no_topics = 10
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(df['ReviewTxt'])
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
lda_model = LatentDirichletAllocation(n_topics=20,               # Number of topics
                                      max_iter=10,               # Max learning iterations
                                      learning_method='online',   
                                      random_state=100,          # Random state
                                      batch_size=128,            # n docs in each learning iter
                                      evaluate_every = -1,       # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(tf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %%
# Define Search Param
search_params = {'n_components': [10, 15, 20, 25, 30], 'learning_decay': [.5, .7, .9]}

# Init the Model
lda = LatentDirichletAllocation()

# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params)

# Do the Grid Search
model.fit(tf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-68a11a8ed24b> in <module>()
#       3
#       4 # Init the Model
# ----> 5 lda = LatentDirichletAllocation()
#       6
#       7 # Init Grid Search Class
#
# NameError: name 'LatentDirichletAllocation' is not defined

# %%
# Best Model
best_lda_model = model.best_estimator_

# Model Parameters
print("Best Model's Params: ", model.best_params_)

# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)

# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(tf))
# Out:
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 10}
# Best Log Likelihood Score:  -6873645.28614
# Model Perplexity:  581.492796927

# %%
# Create Document - Topic Matrix
lda_output = best_lda_model.transform(tf)
# Out:
# array([[ 0.00625   ,  0.00625012,  0.00625   , ...,  0.00625003,
#          0.4148194 ,  0.00625   ],
#        [ 0.00454635,  0.004546  ,  0.0045458 , ...,  0.05785622,
#          0.00454678,  0.00454685],
#        [ 0.00833615,  0.00833559,  0.00833337, ...,  0.00833433,
#          0.00833467,  0.0083349 ],
#        ...,
#        [ 0.06470589,  0.00588236,  0.0058829 , ...,  0.07060998,
#          0.19392902,  0.00588235],
#        [ 0.0022224 ,  0.12959558,  0.0022223 , ...,  0.06651666,
#          0.24918524,  0.0022232 ],
#        [ 0.00185223,  0.07084303,  0.30064189, ...,  0.00185191,
#          0.38302874,  0.00185211]])

# %%
#Topic distribution over the review text
Topic_distribution = DataFrame(data=lda_output)
Topic_distribution.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.006250  0.006250  0.006250  0.006251  0.006250  0.535178  0.006252
# 1  0.004546  0.004546  0.004546  0.210817  0.271782  0.432267  0.004546
# 2  0.008336  0.008336  0.008333  0.231436  0.008335  0.701887  0.008333
# 3  0.004167  0.093301  0.103662  0.239966  0.004168  0.343525  0.004167
# 4  0.003571  0.041577  0.054316  0.434473  0.003572  0.138600  0.003573
#
#           7         8         9
# 0  0.006250  0.414819  0.006250
# 1  0.057856  0.004547  0.004547
# 2  0.008334  0.008335  0.008335
# 3  0.004167  0.157039  0.045838
# 4  0.003571  0.313173  0.003573

# %%
# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(best_lda_model.components_)

# Assign Column and Index
df_topic_keywords.columns = tf_vectorizer.get_feature_names()

# View
df_topic_keywords
# Out:
#             10         100          12           15         1st           20  \
# 0     0.100014    0.100034    0.100035     0.100015    0.100022     0.100020
# 1     0.100017  378.703464    0.100041     0.100023  740.286009     0.100019
# 2     0.100020    0.100037    0.100053     0.100024    0.100035     0.100023
# 3     0.100013    0.100032    0.100034     0.100014    0.100021     0.100017
# 4     0.100013    0.100014  909.402630     0.100012    0.100024     0.100018
# 5     0.100014    0.100019    0.100019     0.100012    0.100016     0.100011
# 6     0.100016    0.100034    0.100047     0.100018    0.100020     0.100017
# 7  6129.089297    0.100034    0.100064  1917.741106    0.100028  1798.322175
# 8     0.100018  587.265796    0.100049     0.100020    0.100028     0.100023
# 9     0.100015    0.100026    0.100034     0.100017    0.100022     0.100018
#
#             30          45        able    absolute     ...            write  \
# 0     0.100018    0.100014    0.100019    0.100023     ...         0.100023
# 1     0.100017    0.100017    0.100027   56.893572     ...         0.100029
# 2     0.100022    0.100020    0.100031   34.850549     ...       616.278315
# 3     0.100015    0.100012  282.151896  667.188964     ...         0.100038
# 4     0.100015    0.100009    0.100021    0.100015     ...         0.100023
# 5     0.100010    0.100010    0.100024    0.100018     ...         0.100023
# 6     0.100015    0.100016    0.100027    0.100029     ...       412.880089
# 7  2312.413777  891.770207    0.100039    0.100025     ...         0.100036
# 8     0.100020    0.100016  714.510285    0.100029     ...         0.100032
# 9     0.100014    0.100012    0.100034    0.100026     ...         0.100027
#
#         wrong        year        years          yes    yesterday       young  \
# 0    0.100017    0.100024     0.100021     0.100027     0.100025    0.100020
# 1    0.100024    0.100036  2953.913214     0.100026     0.100032    0.100020
# 2   88.809827    0.100032     0.100023     0.100035     0.100054    0.100015
# 3    0.100023  347.832137     0.100022  2334.458862  1077.969914  502.042258
# 4    0.100017    0.100020     0.100014     0.100020     0.100025    0.100014
# 5    0.100019    0.100023     0.100013     0.100029     0.100026    0.100013
# 6    0.100016    0.100027     0.100020     0.100029     0.100026    0.100021
# 7  467.519023    0.100028     0.100018     0.100029     0.100035    0.100013
# 8  960.347528  970.763369     0.100021     0.100034     0.100042    0.100015
# 9    0.100025    0.100024     0.100020   345.859286     0.100038    0.100019
#
#           yum        yummy       zomato
# 0  637.276849     0.100042     0.100024
# 1    0.100025     0.100030   938.562498
# 2    0.100029     0.100039  1442.629042
# 3    0.100028  1394.918337     0.100036
# 4    0.100018     0.100018     0.100024
# 5  428.217064  1550.780589     0.100023
# 6    0.100037  1404.846990     0.100026
# 7    0.100023     0.100022     0.100038
# 8  427.243137     0.100027     0.100034
# 9    0.100042     0.100033     0.100022
#
# [10 rows x 1000 columns]

# %%
# choose the best parameter based on this. It should be maximum
# Get Log Likelyhoods from Grid Search Output

n_topics = [10, 15]
log_likelyhoods_5 = [round(gscore.mean_validation_score) for gscore in model.grid_scores_ if gscore.parameters['learning_decay']==0.5]

# Show graph
plt.figure(figsize=(12, 8))
plt.plot(n_topics, log_likelyhoods_5, label='0.5')
plt.title("Choosing Optimal LDA Model")
plt.xlabel("Num Topics")
plt.ylabel("Log Likelyhood Scores")
plt.legend(title='Learning decay', loc='best')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:747: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
# Show top n keywords for each topic
def show_topics(vectorizer=tf_vectorizer, lda_model=lda_model, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

topic_keywords = show_topics(vectorizer=tf_vectorizer, lda_model=best_lda_model, n_words=15)        

# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#           Word 0      Word 1     Word 2     Word 3      Word 4     Word 5  \
# Topic 0    spicy        dosa  authentic     masala      pocket     coffee
# Topic 1   indian  restaurant      north       road       taste      south
# Topic 2  chicken     ordered      order    biryani        rice       fish
# Topic 3    place        just       food       best        time  bangalore
# Topic 4    pizza        beer      floor     drinks       night       good
# Topic 5     food        good      place    service    ambience      great
# Topic 6     home         ice       cake  chocolate       cream  breakfast
# Topic 7       10        wait    service        tea       table       time
# Topic 8     food        good        veg    service  restaurant       like
# Topic 9  chicken       sauce     simple      quite     noodles   tandoori
#
#              Word 6   Word 7    Word 8    Word 9   Word 10     Word 11  \
# Topic 0      garlic   cheese   chutney      pork  sandwich     punjabi
# Topic 1  reasonable   family    dishes     style     years       quite
# Topic 2       taste   paneer      dish  delivery  biriyani       curry
# Topic 3       visit     like       try    people      love        make
# Topic 4       music  paratha      wasn       bar   evening     ordered
# Topic 5        nice   really   awesome       try     visit        best
# Topic 6        open   priced     comes      cafe       hot       fresh
# Topic 7        used   burger      guys       don       bad        dont
# Topic 8        menu   really  starters    buffet      main  experience
# Topic 9       rolls      try     steak      roll    pizzas       water
#
#           Word 12  Word 13     Word 14
# Topic 0    chilli    small       green
# Topic 1       egg     best    visiting
# Topic 2    mutton    fried      cooked
# Topic 3      away    great       staff
# Topic 4   seating     nice       prawn
# Topic 5  ambiance    taste       money
# Topic 6  desserts  veggies         try
# Topic 7       got  minutes     waiting
# Topic 8    course    lunch        just
# Topic 9       red     thai  absolutely
